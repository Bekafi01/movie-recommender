# %%
import pandas as pd
import re

# %%
movies_df = pd.read_csv("..\\data\\ml - 1m\\movies.csv")
ratings_df = pd.read_csv("..\\data\\ml - 1m\\ratings.csv")

# %%
from sqlalchemy import create_engine, Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base

# Create engine
engine = create_engine('sqlite:///../data/movies.db', echo=False)
Base = declarative_base()

# Define the simplified table (only essential columns)
class Movie(Base):
    __tablename__ = 'movies'
    
    movie_id = Column(Integer, primary_key=True)
    title = Column(String)
    year = Column(Integer)
    genres = Column(String)
    rating = Column(Float)           # Average rating from ratings_df

# Create table
Base.metadata.create_all(engine)
print("Database table created successfully!")
# Out:
# Database table created successfully!
# C:\Users\Beka\AppData\Local\Temp\ipykernel_19452\3600389899.py:6: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
# Extract title and year from movies_df
def extract_title_year(title_str):
    """Extracts clean title and year from 'Title (Year)' format"""
    match = re.match(r'^(.*)\s\((\d{4})\)$', title_str.strip())
    if match:
        return match.group(1).strip(), int(match.group(2))
    return title_str.strip(), None

# Apply extraction
movies_df[['clean_title', 'year']] = movies_df['title'].apply(
    lambda x: pd.Series(extract_title_year(x))
)

# %%
# Aggregate ratings: calculate average rating per movie
ratings_agg = ratings_df.groupby('movieId')['rating'].mean().reset_index()
ratings_agg.columns = ['movieId', 'rating']

# Round to nearest whole number and convert to nullable integer
ratings_agg['rating'] = ratings_agg['rating'].round().astype('Int64')

# %%
# Merge dataframes
merged_df = movies_df.merge(ratings_agg, on='movieId', how='left')

# %%
# Select and rename final columns
merged_df = merged_df[[
    'movieId', 'clean_title', 'year', 'genres', 'rating'
]].rename(columns={
    'movieId': 'movie_id',
    'clean_title': 'title'
})

# %%
# Handle missing values
merged_df['rating'] = merged_df['rating'].fillna(0.0)
merged_df['year'] = merged_df['year'].fillna(0).astype(int)

# %%
# Remove duplicates if any (keep first occurrence)
merged_df = merged_df.drop_duplicates(subset=['movie_id'], keep='first')

# %%
# Load into database
merged_df.to_sql('movies', engine, if_exists='replace', index=False)
print(f"Loaded {len(merged_df)} records into the database!")
# Out:
# Loaded 9742 records into the database!

# %%
# Preview result
merged_df.head()
# Out:
#    movie_id                        title  year  \
# 0         1                    Toy Story  1995
# 1         2                      Jumanji  1995
# 2         3             Grumpier Old Men  1995
# 3         4            Waiting to Exhale  1995
# 4         5  Father of the Bride Part II  1995
#
#                                         genres  rating
# 0  Adventure|Animation|Children|Comedy|Fantasy       4
# 1                   Adventure|Children|Fantasy       3
# 2                               Comedy|Romance       3
# 3                         Comedy|Drama|Romance       2
# 4                                       Comedy       3
